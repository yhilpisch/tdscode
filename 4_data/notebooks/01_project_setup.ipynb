# %% [markdown]
# <img src="https://hilpisch.com/tds_logo.png" width="20%" align="right">

# %% [markdown]
# # The Data Scientist
# ## Book 4 · Software Engineering, Reproducibility, and Deployment Basics
# ### Notebook 01 · Project Setup
#
# © Dr. Yves J. Hilpisch<br>AI-Powered by GPT 5.x<br>The Python Quants GmbH | https://tpq.io<br>https://thedatascientist.dev | https://linktr.ee/dyjh

# %% [markdown]
# ### Goals
# - Sketch a clean project tree.
# - Write down a tiny reproducibility checklist.

# %% [markdown]
# ### Checklist
# - `python -m venv .venv`
# - `pip install -r requirements.txt`
# - Keep data in `data/`, notebooks in `notebooks/`, code in `src/`.
# - Add one short `README.md` explaining how to run.

# %% [markdown]
# ### Next
# Run `python code/project_scaffold.py` from `4_data/` to create a starter tree and inspect it.

# %% [markdown]
# <img src="https://hilpisch.com/tds_logo.png" width="20%" align="right">
