# %% [markdown]
# <img src="https://hilpisch.com/tds_logo.png" width="20%" align="right">

# %% [markdown]
# # The Data Scientist
# ## Book 1 · Python Programming Foundations for Data Science
# ### Notebook 01 · Core Types
#
# © Dr. Yves J. Hilpisch<br>AI-Powered by GPT 5.x<br>The Python Quants GmbH | https://tpq.io<br>https://thedatascientist.dev | https://linktr.ee/dyjh

# %% [markdown]
# ### Goals
# - Inspect numbers, strings, lists, and dicts.
# - Practise simple calculations and f-strings.

# %%
price = 19.5
name = 'Ada'
scores = [88, 92, 95]
avg = sum(scores) / len(scores)
print(f'Hello {name}, average score {avg:.1f}, price {price}')

# %% [markdown]
# ### Reflection
# What changes if you add another score? Why?

# %% [markdown]
# <img src="https://hilpisch.com/tds_logo.png" width="20%" align="right">
