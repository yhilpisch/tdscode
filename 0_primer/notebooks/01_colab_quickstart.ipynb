# %% [markdown]
# <img src="../assets/tds_logo.png" width="20%" align="right">

# %% [markdown]
# # The Data Scientist
# ## Book 0 · Python Primer for Data Science
# ### Notebook 01 · Colab Quickstart
#
# © Dr. Yves J. Hilpisch<br>AI-Powered by GPT 5.x<br>The Python Quants GmbH | https://tpq.io<br>https://thedatascientist.dev | https://linktr.ee/dyjh

# %% [markdown]
# ### Why start in Colab
# Colab removes local setup friction so delegates can focus on the study loop: read, run, reflect, and save artifacts. Use this notebook as a template for early practice sessions.

# %% [markdown]
# ### Goals
# - Confirm the runtime and Python version.
# - Create a small artifact in your drive or repo.
# - Practise the read → run → reflect → save loop.

# %%
import platform, sys
print(f'Python version: {platform.python_version()}')
print(f'Executable: {sys.executable}')

# %% [markdown]
# ### Create a tiny artifact
# Use `pathlib` so the same code works in Colab or locally.

# %%
from pathlib import Path
artifact = Path('artifacts') / 'hello_colab.txt'
artifact.parent.mkdir(parents=True, exist_ok=True)
artifact.write_text('Hello from The Data Scientist primer!')
artifact.resolve()

# %% [markdown]
# ### Reflection prompts
# - Where did the file land? Inspect the path above.
# - If you rerun the cell, what stays the same and what changes?
# - How would you explain this tiny artifact in your learning journal?

# %% [markdown]
# <img src="../assets/tds_logo.png" width="20%" align="right">
