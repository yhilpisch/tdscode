# %% [markdown]
# <img src="https://hilpisch.com/tds_logo.png" width="20%" align="right">

# %% [markdown]
# # The Data Scientist
# ## Book 0 · Python Primer for Data Science
# ### Notebook 02 · Notebook Habits
#
# © Dr. Yves J. Hilpisch<br>AI-Powered by GPT 5.x<br>The Python Quants GmbH | https://tpq.io<br>https://thedatascientist.dev | https://linktr.ee/dyjh

# %% [markdown]
# ### Notebook habits to keep runs reproducible
# This notebook mirrors Chapter 4 (Strings, Files, Notebook Habits). Keep the habits visible inside the notebook itself.

# %% [markdown]
# ### Checklist for every session
# - Start with a short Markdown summary of the question.
# - Keep imports together; prefer standard library first.
# - Use `Path` objects for any file access.
# - Save at least one small artifact per session (CSV, TXT, PNG).
# - Add a closing cell that states what you learned.

# %%
from pathlib import Path
data_dir = Path('data')
data_dir.mkdir(exist_ok=True)
notes_file = data_dir / 'session_notes.txt'
notes = [
    'Question: What is the difference between scripts and notebooks?',
    'Action: Saved a tiny artifact to reinforce Path usage.',
    'Result: Verified paths stay relative and portable.',
]
notes_file.write_text('\n'.join(notes))
notes_file.resolve()

# %% [markdown]
# ### Why this matters
# Small, repeatable habits make later modules easier. If every notebook ends with one saved artifact and one reflection line, you build a consistent portfolio trail from day one.

# %% [markdown]
# <img src="https://hilpisch.com/tds_logo.png" width="20%" align="right">
