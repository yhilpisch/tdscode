# %% [markdown]
# <img src="../assets/tds_logo.png" width="20%" align="right">

# %% [markdown]
# # The Data Scientist
# ## Book 2 · Python Data Analysis, Visualization, and Storytelling
# ### Notebook 01 · NumPy and pandas Intro
#
# © Dr. Yves J. Hilpisch<br>AI-Powered by GPT 5.x<br>The Python Quants GmbH | https://tpq.io<br>https://thedatascientist.dev | https://linktr.ee/dyjh

# %% [markdown]
# ### Goals
# - Create a NumPy array and a pandas DataFrame.
# - Compute a simple summary.

# %%
import numpy as np
import pandas as pd
arr = np.array([1, 2, 3, 4])
df = pd.DataFrame({'channel': ['email', 'ads', 'referral'], 'signups': [42, 55, 31]})
print('array mean', arr.mean())
print(df.describe(include='all'))

# %% [markdown]
# ### Next
# Try replacing the numbers with your own small dataset and re-run the summary.

# %% [markdown]
# <img src="../assets/tds_logo.png" width="20%" align="right">
